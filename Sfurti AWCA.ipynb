# %%
import pandas as pd

# %%
df = pd.read_csv('CIGS_v1_4_20211101.csv')

# %%
df
#Add factgrid IDs here
# Out:
#     site_id  accuracy cdli_provenience_id anc_name        transc_name  \
# 0       ABY         3                 104    Abdju             Abīdūs
# 1       ADA         2                   0      NaN             Adalar
# 2       ADB         3                 252     Adab            Bismāyā
# 3       AGR         3                 102  Unknown         Tall Ajrab
# 4       AHT         2                   0      NaN            Ahtamar
# ..      ...       ...                 ...      ...                ...
# 559     ZLB         1                  58      NaN           Zālūl Āb
# 560     ZOH         1                 116      NaN  Sar-i Pol-i Zohāb
# 561     ZTP         3                 244  Tushhan       Ziyaret Tepe
# 562     ZVA         1                   0      NaN        Zvartʻnotsʻ
# 563     ZWY         1                 271      NaN            Zawiyah
#
#     ara_name  arm_name    fas_name geo_name gre_name  ... geonames_id  \
# ...

# %%
df.to_csv("CIGS_with_Factgrid_IDs.csv")
